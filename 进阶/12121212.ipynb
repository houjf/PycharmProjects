# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0.0,1.0,0.01)
s = np.sin(2*np.pi*t)
plt.rcParams['lines.color']='red'
plt.plot(t,s)

c = np.cos(2*np.pi*t)
plt.rcParams['lines.linewidth']='2'
plt.plot(np.arange(0.0,1.0,0.01),c)

plt.show()
